# %%
def sommaduenum(x, y):
  '''somma delle variabili x, y'''
  ris = x + y
  return ris

# %%
somma = sommaduenum(-150, 100)
somma
# Out:
# -50

# %%
def posneg(x):
  if x < 0:
    return'il num è neg'
  elif x == 0:
    return 'il num inserito è zero, cambiare num'
  else:
      return 'il num è pos'

# %%
x = float(input("inserire un numero: "))
if x < 0:
    print('il num è neg')
elif x == 0:
    print( 'il num inserito è zero, cambiare num')
else:
   print( 'il num è pos')
# Out:
# inserire un numero: 5
# il num è pos

# %%
def paridisp(x):
  if x % 2 == 0:
   return 'è un numero pari'
  else:
   return 'il numero è dispari'

# %%
x = int(input("inserisci un numero: "))
if x % 2 == 0:
   print('è un numero pari')
else:
   print('il numero è dispari')
# Out:
# inserisci un numero: 51
# il numero è dispari

# %%
# %%writefile formulario.py

def areatriangolo(b, h):
  A = (b*h)/2
  return A

def perimetrotriangolo(a, b, c):
  P = (a+b+c)
  return P
# Out:
# Overwriting formulario.py

# %%
from formulario import perimetrotriangolo as pt

pt(4,8,9)
# Out:
# 21

# %%
from formulario import areatriangolo as at

# %%
at(4,7)
# Out:
# 14.0

# %%
b = int(input("inserisci la base: "))
h = int(input("inserisci l'altezza: "))
print(areatriangolo(b, h))
# Out:
# inserisci la base: 5
# inserisci l'altezza: 6
# 15.0
